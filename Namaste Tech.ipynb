# %% [markdown]
# ## Importing Libraries

# %%
import json
import requests
import pandas as pd
import numpy as np
import datetime as dt
from pandas.io.json import json_normalize
import mysql.connector
import sqlalchemy

# %% [markdown]
# ## Reading in Q1 orders data from Namaste Tech Github

# %%
# raw Github url for orders.json 
orders_data_url = "https://raw.githubusercontent.com/namasteTechnologies/data-analyst-challenge/master/orders.json"
orders_data_resp = requests.get(orders_data_url)
orders_data = json.loads(orders_data_resp.text)
print(orders_data[0])
# Out:
# {'id': 8369263756632563, 'customer': {'id': 47178, 'name': 'William Doe', 'email': 'william.doe@gmail.com'}, 'total_price': 79.39, 'created_at': '2020-03-07T14:31:11Z', 'line_items': [{'id': 610448, 'product_id': 632910392, 'product_sku': 'PPLEPUNCH20-05', 'product_name': 'Purple Punch 2.0 Dried Flower', 'price': 29.4}, {'id': 997208, 'product_id': 278266679, 'product_sku': 'GPSTASH-01', 'product_name': "Grandpa's Stash Dried Flower", 'price': 49.99}]}

# %%
# converting the raw data to pandas dataframe
orders_df = pd.DataFrame(orders_data)

# changing the data type for created_at to datetime and id to str
orders_df['created_at'] = orders_df['created_at'].astype('datetime64[ns]')
orders_df['id'] = orders_df['id'].astype('str')

# exploding the list if dictionaries in line_items columns to create a separate row for each element in the list
orders_df=orders_df.explode("line_items").reset_index().drop(['index'], axis=1)

# function to convert the dictionaries in the columns to separate columns:
## the keys of the dictionaries will form the columns names and values to the keys will fill up the columns
## dict_column='a' is a random placeholder for string input
def dict_to_col(df, dict_column="a"):
    
    # getting the dictionary keys in a list
    cols = list(df[dict_column][0].keys())
    
    # renaming the columns to add the upper level column name a prefix
    renamed_cols = [dict_column+"_"+x for x in cols]
    
    # creating an empty dictionary with dictionary keys as the columns
    dict_df = pd.DataFrame(columns=cols)
    
    # iterating over the rows to assign values of the keys to their respective columns in the dataframe
    for i,r in df.iterrows():
        dict_values = r[dict_column]
        for x in cols:
            dict_df.loc[i,x]=dict_values[x]
    
    # renaming the columns as per the prefixed names, joining to the orginal dataframe and dropping the dictionary column
    dict_df.columns=renamed_cols
    df = pd.concat([df, dict_df], axis=1)
    df = df.drop([dict_column], axis=1)
    
    return df

# applying the function to the two columns
orders_df = dict_to_col(orders_df, dict_column="customer")
orders_df = dict_to_col(orders_df, dict_column="line_items")

# changing the data type for line_items_price to float
orders_df['line_items_price'] = orders_df['line_items_price'].astype('float64')

# renaming the order based columns
orders_df.rename(columns={'id':'order_id',
                          'created_at':'order_created_date',
                          'total_price':'total_order_price_USD'},
                 inplace=True)

print(orders_df.shape)
print(orders_df.dtypes)
orders_df.head(5)
# Out:
# (37, 11)
# order_id                           object
# total_order_price_USD             float64
# order_created_date         datetime64[ns]
# customer_id                        object
# customer_name                      object
# customer_email                     object
# line_items_id                      object
# line_items_product_id              object
# line_items_product_sku             object
# line_items_product_name            object
# line_items_price                  float64
# dtype: object
#            order_id  total_order_price_USD  order_created_date customer_id  \
# 0  8369263756632563                  79.39 2020-03-07 14:31:11       47178
# 1  8369263756632563                  79.39 2020-03-07 14:31:11       47178
# 2  7262170348080494                  86.98 2020-03-01 09:16:30       94720
# 3  7262170348080494                  86.98 2020-03-01 09:16:30       94720
# 4  7722055557038194                  36.99 2020-01-01 09:17:03       59933
#
#   customer_name          customer_email line_items_id line_items_product_id  \
# 0   William Doe   william.doe@gmail.com        610448             632910392
# 1   William Doe   william.doe@gmail.com        997208             278266679
# 2  Emile Tumson  emile.tumson@gmail.com        997208             278266679
# 3  Emile Tumson  emile.tumson@gmail.com        759658             573794972
# 4   Ethan Jones   ethan.jones@gmail.com        759658             573794972
#
#   line_items_product_sku        line_items_product_name  line_items_price
# 0         PPLEPUNCH20-05  Purple Punch 2.0 Dried Flower             29.40
# 1             GPSTASH-01   Grandpa's Stash Dried Flower             49.99
# 2             GPSTASH-01   Grandpa's Stash Dried Flower             49.99
# 3           SAGENSOUR-01       Sage N Sour Dried Flower             36.99
# 4           SAGENSOUR-01       Sage N Sour Dried Flower             36.99

# %% [markdown]
# ## Reading in exchange rates from https://exchangeratesapi.io/

# %%
forex_df = pd.DataFrame({"date":pd.date_range(start='2019-12-27', end='2020-03-31', freq='D')})

start_date = forex_df['date'].min().date().strftime("%Y-%m-%d")
end_date = forex_df['date'].max().date().strftime("%Y-%m-%d")

rates_data_url = "https://api.exchangeratesapi.io/history"
selection_data = {"start_at":start_date, "end_at":end_date, "base":"USD", "symbols":"USD,CAD"}
rates_data_resp = requests.get(rates_data_url, params=selection_data)
rates_df = pd.DataFrame(json.loads(rates_data_resp.text))

rates_df['forex'] = rates_df['rates'].apply(lambda x: x['CAD'])
rates_df.reset_index(drop=False, inplace=True)
rates_df.rename(columns={'index':'date'}, inplace=True)
rates_df = rates_df[['date','forex']]
rates_df['date'] = rates_df['date'].astype('datetime64[ns]')

forex_df = pd.merge(forex_df, rates_df, on='date', how='left')
forex_df.fillna(method='ffill', inplace=True)
forex_df.head()
# Out:
#         date     forex
# 0 2019-12-27  1.308348
# 1 2019-12-28  1.308348
# 2 2019-12-29  1.308348
# 3 2019-12-30  1.306730
# 4 2019-12-31  1.299448

# %% [markdown]
# ## Connect to MySQL Database

# %%
sqldb_conn = sqlalchemy.create_engine('mysql+mysqlconnector://root:hello123@127.0.0.1:3306/surbhi_namaste_sub', echo=True)

# %load_ext sql

# %sql mysql+mysqlconnector://root:hello123@127.0.0.1:3306/surbhi_namaste_sub
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %% [markdown]
# ## Persist the landed Orders and Forex data into MySQL database

# %%
# 'if_exists' parameter here is set as 'replace', but, 
## otherwise it should be set to 'append' to keep appending landed data into the database landing table
orders_df.to_sql(con=sqldb_conn, name='orders_table', if_exists='replace')
forex_df.to_sql(con=sqldb_conn, name='forex_rate_table', if_exists='replace')
# Out:
# 2020-08-07 20:13:37,950 INFO sqlalchemy.engine.base.Engine DESCRIBE `orders_table`
# 2020-08-07 20:13:37,952 INFO sqlalchemy.engine.base.Engine {}
# 2020-08-07 20:13:37,954 INFO sqlalchemy.engine.base.Engine ROLLBACK
# 2020-08-07 20:13:37,960 INFO sqlalchemy.engine.base.Engine
# CREATE TABLE orders_table (
# 	`index` BIGINT,
# 	order_id TEXT,
# 	`total_order_price_USD` FLOAT(53),
# 	order_created_date DATETIME,
# 	customer_id BIGINT,
# 	customer_name TEXT,
# 	customer_email TEXT,
# 	line_items_id BIGINT,
# 	line_items_product_id BIGINT,
# 	line_items_product_sku TEXT,
# 	line_items_product_name TEXT,
# 	line_items_price FLOAT(53)
# )
#
#
# 2020-08-07 20:13:37,962 INFO sqlalchemy.engine.base.Engine {}
# 2020-08-07 20:13:38,011 INFO sqlalchemy.engine.base.Engine COMMIT
# 2020-08-07 20:13:38,013 INFO sqlalchemy.engine.base.Engine CREATE INDEX ix_orders_table_index ON orders_table (`index`)
# 2020-08-07 20:13:38,015 INFO sqlalchemy.engine.base.Engine {}
# 2020-08-07 20:13:38,051 INFO sqlalchemy.engine.base.Engine COMMIT
# 2020-08-07 20:13:38,055 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2020-08-07 20:13:38,058 INFO sqlalchemy.engine.base.Engine INSERT INTO orders_table (`index`, order_id, `total_order_price_USD`, order_created_date, customer_id, customer_name, customer_email, line_items_id, line_items_product_id, line_items_product_sku, line_items_product_name, line_items_price) VALUES (%(index)s, %(order_id)s, %(total_order_price_USD)s, %(order_created_date)s, %(customer_id)s, %(customer_name)s, %(customer_email)s, %(line_items_id)s, %(line_items_product_id)s, %(line_items_product_sku)s, %(line_items_product_name)s, %(line_items_price)s)
# 2020-08-07 20:13:38,059 INFO sqlalchemy.engine.base.Engine ({'index': 0, 'order_id': '8369263756632563', 'total_order_price_USD': 79.39, 'order_created_date': datetime.datetime(2020, 3, 7, 14, 31, 11), 'customer_id': 47178, 'customer_name': 'William Doe', 'customer_email': 'william.doe@gmail.com', 'line_items_id': 610448, 'line_items_product_id': 632910392, 'line_items_product_sku': 'PPLEPUNCH20-05', 'line_items_product_name': 'Purple Punch 2.0 Dried Flower', 'line_items_price': 29.4}, {'index': 1, 'order_id': '8369263756632563', 'total_order_price_USD': 79.39, 'order_created_date': datetime.datetime(2020, 3, 7, 14, 31, 11), 'customer_id': 47178, 'customer_name': 'William Doe', 'customer_email': 'william.doe@gmail.com', 'line_items_id': 997208, 'line_items_product_id': 278266679, 'line_items_product_sku': 'GPSTASH-01', 'line_items_product_name': "Grandpa's Stash Dried Flower", 'line_items_price': 49.99}, {'index': 2, 'order_id': '7262170348080494', 'total_order_price_USD': 86.98, 'order_created_date': datetime.datetime(2020, 3, 1, 9, 16, 30), 'customer_id': 94720, 'customer_name': 'Emile Tumson', 'customer_email': 'emile.tumson@gmail.com', 'line_items_id': 997208, 'line_items_product_id': 278266679, 'line_items_product_sku': 'GPSTASH-01', 'line_items_product_name': "Grandpa's Stash Dried Flower", 'line_items_price': 49.99}, {'index': 3, 'order_id': '7262170348080494', 'total_order_price_USD': 86.98, 'order_created_date': datetime.datetime(2020, 3, 1, 9, 16, 30), 'customer_id': 94720, 'customer_name': 'Emile Tumson', 'customer_email': 'emile.tumson@gmail.com', 'line_items_id': 759658, 'line_items_product_id': 573794972, 'line_items_product_sku': 'SAGENSOUR-01', 'line_items_product_name': 'Sage N Sour Dried Flower', 'line_items_price': 36.99}, {'index': 4, 'order_id': '7722055557038194', 'total_order_price_USD': 36.99, 'order_created_date': datetime.datetime(2020, 1, 1, 9, 17, 3), 'customer_id': 59933, 'customer_name': 'Ethan Jones', 'customer_email': 'ethan.jones@gmail.com', 'line_items_id': 759658, 'line_items_product_id': 573794972, 'line_items_product_sku': 'SAGENSOUR-01', 'line_items_product_name': 'Sage N Sour Dried Flower', 'line_items_price': 36.99}, {'index': 5, 'order_id': '4280852170163518', 'total_order_price_USD': 55.98, 'order_created_date': datetime.datetime(2020, 3, 10, 11, 59, 46), 'customer_id': 23955, 'customer_name': 'Daniel Smith', 'customer_email': 'daniel.smith@gmail.com', 'line_items_id': 317808, 'line_items_product_id': 477365777, 'line_items_product_sku': 'GOGPR-07', 'line_items_product_name': 'Glueberry OG Pre-Rolls', 'line_items_price': 5.99}, {'index': 6, 'order_id': '4280852170163518', 'total_order_price_USD': 55.98, 'order_created_date': datetime.datetime(2020, 3, 10, 11, 59, 46), 'customer_id': 23955, 'customer_name': 'Daniel Smith', 'customer_email': 'daniel.smith@gmail.com', 'line_items_id': 771854, 'line_items_product_id': 694165761, 'line_items_product_sku': 'HYBTINC-03', 'line_items_product_name': 'Hybrid Blend THC Tincture', 'line_items_price': 49.99}, {'index': 7, 'order_id': '5058732129957127', 'total_order_price_USD': 309.98, 'order_created_date': datetime.datetime(2020, 3, 15, 7, 27, 24), 'customer_id': 59933, 'customer_name': 'Ethan Jones', 'customer_email': 'ethan.jones@gmail.com', 'line_items_id': 604665, 'line_items_product_id': 510650809, 'line_items_product_sku': 'PAX-3', 'line_items_product_name': 'Pax 3 Vaporizer', 'line_items_price': 259.99}  ... displaying 10 of 37 total bound parameter sets ...  {'index': 35, 'order_id': '2212383088430312', 'total_order_price_USD': 142.96, 'order_created_date': datetime.datetime(2020, 1, 22, 21, 26, 52), 'customer_id': 59933, 'customer_name': 'Ethan Jones', 'customer_email': 'ethan.jones@gmail.com', 'line_items_id': 317808, 'line_items_product_id': 477365777, 'line_items_product_sku': 'GOGPR-07', 'line_items_product_name': 'Glueberry OG Pre-Rolls', 'line_items_price': 5.99}, {'index': 36, 'order_id': '2212383088430312', 'total_order_price_USD' ...
# 2020-08-07 20:13:38,067 INFO sqlalchemy.engine.base.Engine COMMIT
# 2020-08-07 20:13:38,074 INFO sqlalchemy.engine.base.Engine DESCRIBE `forex_rate_table`
# 2020-08-07 20:13:38,075 INFO sqlalchemy.engine.base.Engine {}
# 2020-08-07 20:13:38,085 INFO sqlalchemy.engine.base.Engine DESCRIBE `forex_rate_table`
# 2020-08-07 20:13:38,086 INFO sqlalchemy.engine.base.Engine {}
# 2020-08-07 20:13:38,089 INFO sqlalchemy.engine.base.Engine SHOW FULL TABLES FROM `surbhi_namaste_sub`
# 2020-08-07 20:13:38,090 INFO sqlalchemy.engine.base.Engine {}
# 2020-08-07 20:13:38,124 INFO sqlalchemy.engine.base.Engine SHOW CREATE TABLE `forex_rate_table`
# 2020-08-07 20:13:38,125 INFO sqlalchemy.engine.base.Engine {}
# 2020-08-07 20:13:38,133 INFO sqlalchemy.engine.base.Engine
# DROP TABLE forex_rate_table
# 2020-08-07 20:13:38,134 INFO sqlalchemy.engine.base.Engine {}
# 2020-08-07 20:13:38,165 INFO sqlalchemy.engine.base.Engine COMMIT
# 2020-08-07 20:13:38,170 INFO sqlalchemy.engine.base.Engine
# CREATE TABLE forex_rate_table (
# 	`index` BIGINT,
# 	date DATETIME,
# 	forex FLOAT(53)
# )
#
#
# 2020-08-07 20:13:38,171 INFO sqlalchemy.engine.base.Engine {}
# 2020-08-07 20:13:38,210 INFO sqlalchemy.engine.base.Engine COMMIT
# 2020-08-07 20:13:38,212 INFO sqlalchemy.engine.base.Engine CREATE INDEX ix_forex_rate_table_index ON forex_rate_table (`index`)
# 2020-08-07 20:13:38,214 INFO sqlalchemy.engine.base.Engine {}
# 2020-08-07 20:13:38,237 INFO sqlalchemy.engine.base.Engine COMMIT
# 2020-08-07 20:13:38,241 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2020-08-07 20:13:38,245 INFO sqlalchemy.engine.base.Engine INSERT INTO forex_rate_table (`index`, date, forex) VALUES (%(index)s, %(date)s, %(forex)s)
# 2020-08-07 20:13:38,247 INFO sqlalchemy.engine.base.Engine ({'index': 0, 'date': datetime.datetime(2019, 12, 27, 0, 0), 'forex': 1.3083475298}, {'index': 1, 'date': datetime.datetime(2019, 12, 28, 0, 0), 'forex': 1.3083475298}, {'index': 2, 'date': datetime.datetime(2019, 12, 29, 0, 0), 'forex': 1.3083475298}, {'index': 3, 'date': datetime.datetime(2019, 12, 30, 0, 0), 'forex': 1.3067298239}, {'index': 4, 'date': datetime.datetime(2019, 12, 31, 0, 0), 'forex': 1.299448104}, {'index': 5, 'date': datetime.datetime(2020, 1, 1, 0, 0), 'forex': 1.299448104}, {'index': 6, 'date': datetime.datetime(2020, 1, 2, 0, 0), 'forex': 1.299830251}, {'index': 7, 'date': datetime.datetime(2020, 1, 3, 0, 0), 'forex': 1.2981968243}  ... displaying 10 of 96 total bound parameter sets ...  {'index': 94, 'date': datetime.datetime(2020, 3, 30, 0, 0), 'forex': 1.4161682074}, {'index': 95, 'date': datetime.datetime(2020, 3, 31, 0, 0), 'forex': 1.4254289887})
# 2020-08-07 20:13:38,253 INFO sqlalchemy.engine.base.Engine COMMIT

# %%
# %%sql
#
# select * from orders_table;
# Out:
#    mysql+mysqlconnector://root:***@127.0.0.1:3306/
#  * mysql+mysqlconnector://root:***@127.0.0.1:3306/surbhi_namaste_sub
# 37 rows affected.
# [(0, 8369263756632563, 79.39, datetime.datetime(2020, 3, 7, 14, 31, 11), 47178, 'William Doe', 'william.doe@gmail.com', 610448, 632910392, 'PPLEPUNCH20-05', 'Purple Punch 2.0 Dried Flower', 29.4),
#  (1, 8369263756632563, 79.39, datetime.datetime(2020, 3, 7, 14, 31, 11), 47178, 'William Doe', 'william.doe@gmail.com', 997208, 278266679, 'GPSTASH-01', "Grandpa's Stash Dried Flower", 49.99),
#  (2, 7262170348080494, 86.98, datetime.datetime(2020, 3, 1, 9, 16, 30), 94720, 'Emile Tumson', 'emile.tumson@gmail.com', 997208, 278266679, 'GPSTASH-01', "Grandpa's Stash Dried Flower", 49.99),
#  (3, 7262170348080494, 86.98, datetime.datetime(2020, 3, 1, 9, 16, 30), 94720, 'Emile Tumson', 'emile.tumson@gmail.com', 759658, 573794972, 'SAGENSOUR-01', 'Sage N Sour Dried Flower', 36.99),
#  (4, 7722055557038194, 36.99, datetime.datetime(2020, 1, 1, 9, 17, 3), 59933, 'Ethan Jones', 'ethan.jones@gmail.com', 759658, 573794972, 'SAGENSOUR-01', 'Sage N Sour Dried Flower', 36.99),
#  (5, 4280852170163518, 55.98, datetime.datetime(2020, 3, 10, 11, 59, 46), 23955, 'Daniel Smith', 'daniel.smith@gmail.com', 317808, 477365777, 'GOGPR-07', 'Glueberry OG Pre-Rolls', 5.99),
#  (6, 4280852170163518, 55.98, datetime.datetime(2020, 3, 10, 11, 59, 46), 23955, 'Daniel Smith', 'daniel.smith@gmail.com', 771854, 694165761, 'HYBTINC-03', 'Hybrid Blend THC Tincture', 49.99),
#  (7, 5058732129957127, 309.98, datetime.datetime(2020, 3, 15, 7, 27, 24), 59933, 'Ethan Jones', 'ethan.jones@gmail.com', 604665, 510650809, 'PAX-3', 'Pax 3 Vaporizer', 259.99),
#  (8, 5058732129957127, 309.98, datetime.datetime(2020, 3, 15, 7, 27, 24), 59933, 'Ethan Jones', 'ethan.jones@gmail.com', 997208, 278266679, 'GPSTASH-01', "Grandpa's Stash Dried Flower", 49.99),
#  (9, 6431399815998774, 315.97, datetime.datetime(2020, 3, 12, 7, 16, 7), 23955, 'Daniel Smith', 'daniel.smith@gmail.com', 997208, 278266679, 'GPSTASH-01', "Grandpa's Stash Dried Flower", 49.99),
#  (10, 6431399815998774, 315.97, datetime.datetime(2020, 3, 12, 7, 16, 7), 23955, 'Daniel Smith', 'daniel.smith@gmail.com', 317808, 477365777, 'GOGPR-07', 'Glueberry OG Pre-Rolls', 5.99),
#  (11, 6431399815998774, 315.97, datetime.datetime(2020, 3, 12, 7, 16, 7), 23955, 'Daniel Smith', 'daniel.smith@gmail.com', 604665, 510650809, 'PAX-3', 'Pax 3 Vaporizer', 259.99),
#  (12, 5791957346866373, 36.99, datetime.datetime(2020, 3, 24, 9, 52, 40), 47178, 'William Doe', 'william.doe@gmail.com', 759658, 573794972, 'SAGENSOUR-01', 'Sage N Sour Dried Flower', 36.99),
#  (13, 2079640804901496, 55.98, datetime.datetime(2020, 2, 19, 19, 33, 57), 23955, 'Daniel Smith', 'daniel.smith@gmail.com', 317808, 477365777, 'GOGPR-07', 'Glueberry OG Pre-Rolls', 5.99),
#  (14, 2079640804901496, 55.98, datetime.datetime(2020, 2, 19, 19, 33, 57), 23955, 'Daniel Smith', 'daniel.smith@gmail.com', 771854, 694165761, 'HYBTINC-03', 'Hybrid Blend THC Tincture', 49.99),
#  (15, 2249838395290890, 309.98, datetime.datetime(2020, 3, 13, 12, 15, 51), 47178, 'William Doe', 'william.doe@gmail.com', 604665, 510650809, 'PAX-3', 'Pax 3 Vaporizer', 259.99),
#  (16, 2249838395290890, 309.98, datetime.datetime(2020, 3, 13, 12, 15, 51), 47178, 'William Doe', 'william.doe@gmail.com', 997208, 278266679, 'GPSTASH-01', "Grandpa's Stash Dried Flower", 49.99),
#  (17, 7638742701884072, 35.39, datetime.datetime(2020, 3, 8, 5, 28, 1), 59933, 'Ethan Jones', 'ethan.jones@gmail.com', 317808, 477365777, 'GOGPR-07', 'Glueberry OG Pre-Rolls', 5.99),
#  (18, 7638742701884072, 35.39, datetime.datetime(2020, 3, 8, 5, 28, 1), 59933, 'Ethan Jones', 'ethan.jones@gmail.com', 610448, 632910392, 'PPLEPUNCH20-05', 'Purple Punch 2.0 Dried Flower', 29.4),
#  (19, 5307192536865304, 86.98, datetime.datetime(2020, 3, 12, 1, 40, 57), 47178, 'William Doe', 'william.doe@gmail.com', 997208, 278266679, 'GPSTASH-01', "Grandpa's Stash Dried Flower", 49.99),
#  (20, 5307192536865304, 86.98, datetime.datetime(2020, 3, 12, 1, 40, 57), 47178, 'William Doe', 'william.doe@gmail.com', 759658, 573794972, 'SAGENSOUR-01', 'Sage N Sour Dried Flower', 36.99),
#  (21, 8662976573169716, 5.99, datetime.datetime(2020, 2, 5, 10, 22, 49), 94720, 'Emile Tumson', 'emile.tumson@gmail.com', 317808, 477365777, 'GOGPR-07', 'Glueberry OG Pre-Rolls', 5.99),
#  (22, 2366621613260728, 259.99, datetime.datetime(2020, 1, 18, 12, 46, 12), 23955, 'Daniel Smith', 'daniel.smith@gmail.com', 604665, 510650809, 'PAX-3', 'Pax 3 Vaporizer', 259.99),
#  (23, 9786845594710809, 79.39, datetime.datetime(2020, 3, 18, 13, 43, 24), 59933, 'Ethan Jones', 'ethan.jones@gmail.com', 771854, 694165761, 'HYBTINC-03', 'Hybrid Blend THC Tincture', 49.99),
#  (24, 9786845594710809, 79.39, datetime.datetime(2020, 3, 18, 13, 43, 24), 59933, 'Ethan Jones', 'ethan.jones@gmail.com', 610448, 632910392, 'PPLEPUNCH20-05', 'Purple Punch 2.0 Dried Flower', 29.4),
#  (25, 6255086600405590, 55.98, datetime.datetime(2020, 1, 5, 9, 41, 30), 94720, 'Emile Tumson', 'emile.tumson@gmail.com', 997208, 278266679, 'GPSTASH-01', "Grandpa's Stash Dried Flower", 49.99),
#  (26, 6255086600405590, 55.98, datetime.datetime(2020, 1, 5, 9, 41, 30), 94720, 'Emile Tumson', 'emile.tumson@gmail.com', 317808, 477365777, 'GOGPR-07', 'Glueberry OG Pre-Rolls', 5.99),
#  (27, 5235927587417736, 36.99, datetime.datetime(2020, 3, 24, 7, 12, 33), 94720, 'Emile Tumson', 'emile.tumson@gmail.com', 759658, 573794972, 'SAGENSOUR-01', 'Sage N Sour Dried Flower', 36.99),
#  (28, 5825547264855968, 55.98, datetime.datetime(2020, 1, 1, 12, 59, 26), 59933, 'Ethan Jones', 'ethan.jones@gmail.com', 771854, 694165761, 'HYBTINC-03', 'Hybrid Blend THC Tincture', 49.99),
#  (29, 5825547264855968, 55.98, datetime.datetime(2020, 1, 1, 12, 59, 26), 59933, 'Ethan Jones', 'ethan.jones@gmail.com', 317808, 477365777, 'GOGPR-07', 'Glueberry OG Pre-Rolls', 5.99),
#  (30, 1288301820842508, 29.4, datetime.datetime(2020, 1, 19, 3, 53, 34), 23955, 'Daniel Smith', 'daniel.smith@gmail.com', 610448, 632910392, 'PPLEPUNCH20-05', 'Purple Punch 2.0 Dried Flower', 29.4),
#  (31, 1104846479586545, 86.98, datetime.datetime(2020, 2, 22, 21, 44, 5), 94720, 'Emile Tumson', 'emile.tumson@gmail.com', 997208, 278266679, 'GPSTASH-01', "Grandpa's Stash Dried Flower", 49.99),
#  (32, 1104846479586545, 86.98, datetime.datetime(2020, 2, 22, 21, 44, 5), 94720, 'Emile Tumson', 'emile.tumson@gmail.com', 759658, 573794972, 'SAGENSOUR-01', 'Sage N Sour Dried Flower', 36.99),
#  (33, 2212383088430312, 142.96, datetime.datetime(2020, 1, 22, 21, 26, 52), 59933, 'Ethan Jones', 'ethan.jones@gmail.com', 997208, 278266679, 'GPSTASH-01', "Grandpa's Stash Dried Flower", 49.99),
#  (34, 2212383088430312, 142.96, datetime.datetime(2020, 1, 22, 21, 26, 52), 59933, 'Ethan Jones', 'ethan.jones@gmail.com', 759658, 573794972, 'SAGENSOUR-01', 'Sage N Sour Dried Flower', 36.99),
#  (35, 2212383088430312, 142.96, datetime.datetime(2020, 1, 22, 21, 26, 52), 59933, 'Ethan Jones', 'ethan.jones@gmail.com', 317808, 477365777, 'GOGPR-07', 'Glueberry OG Pre-Rolls', 5.99),
#  (36, 2212383088430312, 142.96, datetime.datetime(2020, 1, 22, 21, 26, 52), 59933, 'Ethan Jones', 'ethan.jones@gmail.com', 771854, 694165761, 'HYBTINC-03', 'Hybrid Blend THC Tincture', 49.99)]
